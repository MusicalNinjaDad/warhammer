# %%
from IPython.display import Markdown

from wfrp import NPCs, Warhammer, careers  # noqa: F401
from wfrp.beasts import *

# %% [markdown]
# ## Giants, Ogres, Trolls

# %%
Giant()

# %%
Ogre()

# %%
Troll()

# %% [markdown]
# # Dwarves

# %%
Dwarf()

# %%
Dwarf() + careers.Giant_Slayer

# %% [markdown]
# ## Karak Zabam
#
# ### Senior guardsman Björn Björnsson III ("Backdoor")
#
# - Never had the opportunity to offer hospitality to friends of dwarves before:
#   > *"What you messing about at out there Backdoor?"*
#   >
#   > *"Keep your beard straight Flatfoot ... I've been waiting all my life for this ..."*
#   - Piece of ore before entering
#   - Beer at the central hearth (Foambeards brew in honour of you)

# %%
display(Markdown((Dwarf() + careers.Watchman).as_table()))

# %% [markdown]
# ### Master Runesmith Grunni Thurgromsson ("Flatfoot")
#
# - Left foot very wide & flat - dropped anvil on his foot as an apprentice
# - 550 years old

# %%
display(Markdown((Dwarf() + careers.Rune_Lord).as_table()))

# %% [markdown]
# ### Apprentice Guardswoman Valma Grunnasdottir ("Birdfood")
#
# - Name found - celebrate

# %%
display(Markdown((Dwarf()).as_table()))

# %% [markdown]
# ### Names
#
# | d10 | Male | Female
# |:-|:-|:-|
# | 1 | Kazadar Grundissun | Karelia Solveigsdottir
# | 2 | Drumin Drongssun | Throlin Frigasdottir
# | 3 | Kazran Kettrisson | Berta Dureesdottir
# | 4 | Belegar Yannisson | Modra Throlinsdottir
# | 5 | Cranneg Bradnissun | Karelia Kareliasdottir
# | 6 | Thungni Thrundssun | Thoda Hunnisdottir
# | 7 | Sundrim Fimbursson | Derna Trunnisdottir
# | 8 | Grumdin Grunnisson | Katrin Dernasdottir
# | 9 | Vikram Mundrissun |  Grondi Gertasdottir
# | 10 | Drumin Logansson | Ferna Sunnisdottir

# %% [markdown]
# # Norscans

# %%
Human()

# %%
Warrior_Of_Chaos()

# %% [markdown]
# # Dragon
#
# ## Lair
#
# - Streams of lava
# - Forge hidden behind Ratar
#
# ## Characteristics
#
# - Bright orange scales
# - Heat
# - Psychic
# - Truth
# - Deep rumbling voice
#
# ## Name - Ratar
# "Call me Ratar. You wouldn't be able to pronounce my full name."
#
# **Surratarvuremmulin**
#
# Images of:
# - Lava
# - Lights in a wide open sky
# - Green forests
#
# Jumble of feelings:
# - from hunger, to sadness, to relaxed bliss
# - WP test: at one point you start laughing uncontrollably
#
# ## Trapped / Resigned
#
# - "Oh great another dwarf come to commit suicide by dragon... What's up with your hair? Didn't even have the shame to colour it?"
# - Used to be friends with the dwarves when they first came here - shared love of smithing. My millenia ago. They seem to have forgotten me now though
# - Dark magics course through the valley outside
# - Humans (spits - melts rock) trapped me here & stole my egg
# - They were working with Aard the Skyvark
# - If I leave this cave the egg will hatch & Aard will steal the child

# %% [markdown]
# # Aard the Skyvark
#
# **4A**
# - 1 peck, 2 claw, 1 tail
# - venomous tail (**T** -> drowsy; 2nd fail -> unconscious; 3rd fail -> dead in 2D6 rounds)
#
# **magic**
# - can move through stone
#
# **home**
# - Egg is in a sealed cavern behind the eerie

# %%
display(Markdown((Manticore()).as_table()))
